# %%
from contract_feature_handler import ContractFeatureHandler
from classification_evaluator import ClassificationEvaluator
import pandas as pd
import os

os.environ["no_proxy"] = "127.0.0.1"
# os.environ["CUDA_VISIBLE_DEVICES"] = "0,1"

contract_address = "0x793248B40477Ce96bf08aEAB3f9447c99B9c80E7"

contract_handler = ContractFeatureHandler(contract_address, debug_flag=True, platform="bsc")
if contract_handler.gigahorse_status != 'OK':
    print('Gigahorse ERROR!')
else:    
    df_tmp = pd.DataFrame([contract_handler.features])
    classificationEvaluator = ClassificationEvaluator()
    classificationEvaluator.evaluate_single(df_tmp)
    classificationEvaluator.evaluate_hybrid(df_tmp)
# Out:
# getTxHashInfo done! Execution time: 1.3044612407684326 s
# getVerifyTagInfo done! Execution time: 0.33753061294555664 s
# https://go.getblock.io/fee933d1f102465ca3615159bf256fd3
# getTxInfo done! Execution time: 0.9332022666931152 s
# https://go.getblock.io/fee933d1f102465ca3615159bf256fd3
# getCode response: {"jsonrpc":"2.0","id":1,"result":"..."}
# getBytecodeInfo done! Execution time: 0.4867274761199951 s
# getGasUsedInfo done! Execution time: 0.3330872058868408 s
# Error querying address 0x5a9efb4f07bbdc4b40ae12dcc9782e7591e33333: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# Error querying address 0x5a9efb4f07bbdc4b40ae12dcc9782e7591e33333: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# Error querying address 0x5a9efb4f07bbdc4b40ae12dcc9782e7591e33333: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# ...

# %%
import pandas as pd

file_path = "eth_exp.xlsx"
df = pd.read_excel(file_path)  # 确保文件路径正确

# 获取第一列的所有值并转成列表
first_column_values = df.iloc[:, 0].dropna().tolist()

print(first_column_values)
# Out:
# ['contract address', '0x004e4ceb12096d9ccd03efd342b8c2a794293032', '0xe2cb4716c340b6b8a4719706d01c4f1c4412cfe0', '0x1e2e85bc32fb743e8d67b1420df8e7b33dfba091', '0xfd51531b26f9be08240f7459eea5be80d5b047d9', '0x37446b2b6cb533cf0de47b6623825c48a507a880', '0xb1a3d1ee5537550c4adde8dc422ef0edd07974fe']

# %%
len(first_column_values)
# Out:
# 7

# %%
from contract_feature_handler import ContractFeatureHandler
from classification_evaluator import ClassificationEvaluator
import pandas as pd
import os

os.environ["no_proxy"] = "127.0.0.1"

res = {}
def procoss_address(address):
    contract_handler = ContractFeatureHandler(address, debug_flag=True, platform="eth")
    if contract_handler.gigahorse_status != 'OK':
        print('Gigahorse ERROR!')
    else:    
        df_tmp = pd.DataFrame([contract_handler.features])
        classificationEvaluator = ClassificationEvaluator()
        classificationEvaluator.evaluate_single(df_tmp)
        # classificationEvaluator.evaluate_hybrid(df_tmp)
        res[address] = classificationEvaluator.evaluate_hybrid(df_tmp)
        print(f"Processed address: {address}, Result: {res[address]}")
        
for address in first_column_values[1:]:
    print(f"Processing address: {address}")
    procoss_address(address)
    print(f"Processed address: {address}")

# 将结果保存到文件
output_file = "eth.json"
import json
with open(output_file, 'w') as f:
    json.dump(res, f, indent=4)
print(f"Results saved to {output_file}")
# 处理完所有地址后，输出结果
print("All addresses processed.")
# Out:
# 2025-06-11 22:18:02.227104: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-11 22:18:02.228836: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-11 22:18:02.234047: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-11 22:18:02.249927: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...

# %%
import re

# 假设日志内容存储在一个字符串变量 `log_content`
log_content = """
2025-06-11 22:00:16.491267: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
2025-06-11 22:00:16.492995: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
2025-06-11 22:00:16.498167: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
2025-06-11 22:00:16.514119: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
2025-06-11 22:00:16.540945: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
2025-06-11 22:00:16.548697: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
2025-06-11 22:00:16.567525: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
2025-06-11 22:00:18.029216: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
Processing address: 0x6dab590b90e6ab94d6031fb39dd21b4776ee4684
getTxHashInfo done! Execution time: 0.6702072620391846 s
getVerifyTagInfo done! Execution time: 0.3457965850830078 s
https://eth-mainnet.g.alchemy.com/v2/6t0LpEw9cr0OlGIVTFqs92aOIkfhktMk
getTxInfo done! Execution time: 0.35402870178222656 s
https://eth-mainnet.g.alchemy.com/v2/6t0LpEw9cr0OlGIVTFqs92aOIkfhktMk
getCode response: {"jsonrpc":"2.0","id":1,"result":"..."}
getBytecodeInfo done! Execution time: 0.5211925506591797 s
getGasUsedInfo done! Execution time: 0.16098785400390625 s
getGigahorseInfo done! Execution time: 15.410492181777954 s
Total execution time: 17.46270513534546 s
Gigahorse status: OK
The Logistic_Regression model has been successfully loaded.
The Decision_Trees_Classifier model has been successfully loaded.
The Random_Forest_Classifier model has been successfully loaded.
The XGBoost_Classifier model has been successfully loaded.
Single Models load ok!
INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
2025-06-11 22:00:37.414313: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2343] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
Skipping registering GPU devices...
Number of GPUs: 1
HybridModel load ok!
Scaler load ok!
Logistic_Regression           ===> [0.3567383208913933]
Decision_Trees_Classifier     ===> [0.0]
Random_Forest_Classifier      ===> [0.8]
XGBoost_Classifier            ===> [0.15920098]
1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
meta_model  ===> [0.3]
Processed address: 0x6dab590b90e6ab94d6031fb39dd21b4776ee4684, Result: [0.3]
Processed address: 0x6dab590b90e6ab94d6031fb39dd21b4776ee4684
Processing address: 0x2a6aa49b9138b66ba2b81c33435d01c84848afbc
getTxHashInfo done! Execution time: 0.6553032398223877 s
getVerifyTagInfo done! Execution time: 0.36397504806518555 s
https://eth-mainnet.g.alchemy.com/v2/6t0LpEw9cr0OlGIVTFqs92aOIkfhktMk
getTxInfo done! Execution time: 0.3419151306152344 s
https://eth-mainnet.g.alchemy.com/v2/6t0LpEw9cr0OlGIVTFqs92aOIkfhktMk
getCode response: {"jsonrpc":"2.0","id":1,"result":"..."}
getBytecodeInfo done! Execution time: 0.7314400672912598 s
getGasUsedInfo done! Execution time: 0.13987302780151367 s
Error querying address 0xba12222222228d8ba445958a75a0704d566bf2c8: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xd9e1ce17f2641f24ae83637ab66a2cca9c378b9f: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xe39b5e3b6d74016b2f6a9673d7d7493b6df549d5: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xba12222222228d8ba445958a75a0704d566bf2c8: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xba12222222228d8ba445958a75a0704d566bf2c8: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xba12222222228d8ba445958a75a0704d566bf2c8: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xba12222222228d8ba445958a75a0704d566bf2c8: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x87870bca3f3fd6335c3f4ce8392d69350b4fa4e2: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xba12222222228d8ba445958a75a0704d566bf2c8: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xba12222222228d8ba445958a75a0704d566bf2c8: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xe39b5e3b6d74016b2f6a9673d7d7493b6df549d5: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xba12222222228d8ba445958a75a0704d566bf2c8: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xba12222222228d8ba445958a75a0704d566bf2c8: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
getGigahorseInfo done! Execution time: 46.49325466156006 s
Total execution time: 48.72576117515564 s
Gigahorse status: OK
The Logistic_Regression model has been successfully loaded.
The Decision_Trees_Classifier model has been successfully loaded.
The Random_Forest_Classifier model has been successfully loaded.
The XGBoost_Classifier model has been successfully loaded.
Single Models load ok!
INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
Number of GPUs: 1
HybridModel load ok!
Scaler load ok!
Logistic_Regression           ===> [0.9517052864036437]
Decision_Trees_Classifier     ===> [1.0]
Random_Forest_Classifier      ===> [0.8]
XGBoost_Classifier            ===> [0.9485637]
1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step
meta_model  ===> [0.1]
Processed address: 0x2a6aa49b9138b66ba2b81c33435d01c84848afbc, Result: [0.1]
Processed address: 0x2a6aa49b9138b66ba2b81c33435d01c84848afbc
Processing address: 0x193E045BeE45C7573Ff89b12601C745AF739CE67
getTxHashInfo done! Execution time: 0.6820571422576904 s
getVerifyTagInfo done! Execution time: 0.34476518630981445 s
https://eth-mainnet.g.alchemy.com/v2/6t0LpEw9cr0OlGIVTFqs92aOIkfhktMk
getTxInfo done! Execution time: 0.32046055793762207 s
https://eth-mainnet.g.alchemy.com/v2/6t0LpEw9cr0OlGIVTFqs92aOIkfhktMk
getCode response: {"jsonrpc":"2.0","id":1,"result":"..."}
getBytecodeInfo done! Execution time: 0.6805250644683838 s
getGasUsedInfo done! Execution time: 0.19928765296936035 s
Error querying address 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
getGigahorseInfo done! Execution time: 30.362264394760132 s
Total execution time: 32.589359998703 s
Gigahorse status: OK
The Logistic_Regression model has been successfully loaded.
The Decision_Trees_Classifier model has been successfully loaded.
The Random_Forest_Classifier model has been successfully loaded.
The XGBoost_Classifier model has been successfully loaded.
Single Models load ok!
INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
Number of GPUs: 1
HybridModel load ok!
Scaler load ok!
Logistic_Regression           ===> [0.8943216665610196]
Decision_Trees_Classifier     ===> [0.0]
Random_Forest_Classifier      ===> [0.4]
XGBoost_Classifier            ===> [0.7158521]
1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
meta_model  ===> [0.6]
Processed address: 0x193E045BeE45C7573Ff89b12601C745AF739CE67, Result: [0.6]
Processed address: 0x193E045BeE45C7573Ff89b12601C745AF739CE67
Processing address: 0x21a624e893e43d2d36b178fd258ec465aba0ed55
getTxHashInfo done! Execution time: 0.6296634674072266 s
getVerifyTagInfo done! Execution time: 0.318248987197876 s
https://eth-mainnet.g.alchemy.com/v2/6t0LpEw9cr0OlGIVTFqs92aOIkfhktMk
getTxInfo done! Execution time: 0.32690930366516113 s
https://eth-mainnet.g.alchemy.com/v2/6t0LpEw9cr0OlGIVTFqs92aOIkfhktMk
getCode response: {"jsonrpc":"2.0","id":1,"result":"..."}
getBytecodeInfo done! Execution time: 0.9473516941070557 s
getGasUsedInfo done! Execution time: 0.1468372344970703 s
Error querying address 0xa3f6accd609c656c145cae5280e743b544c69c5f: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xba12222222228d8ba445958a75a0704d566bf2c8: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xba12222222228d8ba445958a75a0704d566bf2c8: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xa3f6accd609c656c145cae5280e743b544c69c5f: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xc9f93163c99695c6526b799ebca2207fdf7d61ad: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xdac17f958d2ee523a2206206994597c13d831ec7: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x3416cf6c708da44db2624d63ea0aaef7113527c6: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xc9f93163c99695c6526b799ebca2207fdf7d61ad: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xdac17f958d2ee523a2206206994597c13d831ec7: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x3416cf6c708da44db2624d63ea0aaef7113527c6: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xc9f93163c99695c6526b799ebca2207fdf7d61ad: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x3416cf6c708da44db2624d63ea0aaef7113527c6: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xdac17f958d2ee523a2206206994597c13d831ec7: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x4e68ccd3e89f51c3074ca5072bbac773960dfa36: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xc9f93163c99695c6526b799ebca2207fdf7d61ad: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x3416cf6c708da44db2624d63ea0aaef7113527c6: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xdac17f958d2ee523a2206206994597c13d831ec7: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x4e68ccd3e89f51c3074ca5072bbac773960dfa36: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x3058ef90929cb8180174d74c507176cca6835d73: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x3416cf6c708da44db2624d63ea0aaef7113527c6: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x89b78cfa322f6c5de0abceecab66aee45393cc5a: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x60594a405d53811d3bc4766596efd80fd545a270: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x3058ef90929cb8180174d74c507176cca6835d73: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x89b78cfa322f6c5de0abceecab66aee45393cc5a: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xdac17f958d2ee523a2206206994597c13d831ec7: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x3416cf6c708da44db2624d63ea0aaef7113527c6: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x3058ef90929cb8180174d74c507176cca6835d73: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x6b175474e89094c44da98b954eedeac495271d0f: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x89b78cfa322f6c5de0abceecab66aee45393cc5a: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x3416cf6c708da44db2624d63ea0aaef7113527c6: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xdac17f958d2ee523a2206206994597c13d831ec7: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x4e68ccd3e89f51c3074ca5072bbac773960dfa36: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x3058ef90929cb8180174d74c507176cca6835d73: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x3416cf6c708da44db2624d63ea0aaef7113527c6: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x89b78cfa322f6c5de0abceecab66aee45393cc5a: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x6b175474e89094c44da98b954eedeac495271d0f: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x60594a405d53811d3bc4766596efd80fd545a270: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
getGigahorseInfo done! Execution time: 24.18671727180481 s
Total execution time: 26.5557279586792 s
Gigahorse status: OK
The Logistic_Regression model has been successfully loaded.
The Decision_Trees_Classifier model has been successfully loaded.
The Random_Forest_Classifier model has been successfully loaded.
The XGBoost_Classifier model has been successfully loaded.
Single Models load ok!
INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
Number of GPUs: 1
HybridModel load ok!
Scaler load ok!
Logistic_Regression           ===> [0.6790837753082518]
Decision_Trees_Classifier     ===> [0.0]
Random_Forest_Classifier      ===> [0.2]
XGBoost_Classifier            ===> [0.04170226]
1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step
meta_model  ===> [0.3]
Processed address: 0x21a624e893e43d2d36b178fd258ec465aba0ed55, Result: [0.3]
Processed address: 0x21a624e893e43d2d36b178fd258ec465aba0ed55
Processing address: 0xb65c2ba401d5fcb60dfa748fe80b69525c47fd5e
getTxHashInfo done! Execution time: 0.640223503112793 s
getVerifyTagInfo done! Execution time: 0.2959098815917969 s
https://eth-mainnet.g.alchemy.com/v2/6t0LpEw9cr0OlGIVTFqs92aOIkfhktMk
getTxInfo done! Execution time: 0.3134751319885254 s
https://eth-mainnet.g.alchemy.com/v2/6t0LpEw9cr0OlGIVTFqs92aOIkfhktMk
getCode response: {"jsonrpc":"2.0","id":1,"result":"..."}
getBytecodeInfo done! Execution time: 0.5327246189117432 s
getGasUsedInfo done! Execution time: 0.1613473892211914 s
getGigahorseInfo done! Execution time: 12.617974042892456 s
Total execution time: 14.561654567718506 s
Gigahorse status: OK
The Logistic_Regression model has been successfully loaded.
The Decision_Trees_Classifier model has been successfully loaded.
The Random_Forest_Classifier model has been successfully loaded.
The XGBoost_Classifier model has been successfully loaded.
Single Models load ok!
INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
Number of GPUs: 1
HybridModel load ok!
Scaler load ok!
Logistic_Regression           ===> [0.5006358635238661]
Decision_Trees_Classifier     ===> [1.0]
Random_Forest_Classifier      ===> [1.0]
XGBoost_Classifier            ===> [0.9995505]
WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f9ff05a4d60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step
meta_model  ===> [0.9]
Processed address: 0xb65c2ba401d5fcb60dfa748fe80b69525c47fd5e, Result: [0.9]
Processed address: 0xb65c2ba401d5fcb60dfa748fe80b69525c47fd5e
Processing address: 0x7b83c834317bb1851506aa74c46b252584805b1c
getTxHashInfo done! Execution time: 0.6731939315795898 s
getVerifyTagInfo done! Execution time: 0.3372616767883301 s
https://eth-mainnet.g.alchemy.com/v2/6t0LpEw9cr0OlGIVTFqs92aOIkfhktMk
getTxInfo done! Execution time: 0.3016176223754883 s
https://eth-mainnet.g.alchemy.com/v2/6t0LpEw9cr0OlGIVTFqs92aOIkfhktMk
getCode response: {"jsonrpc":"2.0","id":1,"result":"..."}
getBytecodeInfo done! Execution time: 0.5004172325134277 s
getGasUsedInfo done! Execution time: 0.14608550071716309 s
Error querying address 0x80409a47b1b7cb948ce08ff96cd86d5de1203562: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x99fa6bfa8959a1b9b80a24a0b0188096fe254d07: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x99fa6bfa8959a1b9b80a24a0b0188096fe254d07: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x99fa6bfa8959a1b9b80a24a0b0188096fe254d07: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
getGigahorseInfo done! Execution time: 6.991288423538208 s
Total execution time: 8.949864387512207 s
Gigahorse status: OK
The Logistic_Regression model has been successfully loaded.
The Decision_Trees_Classifier model has been successfully loaded.
The Random_Forest_Classifier model has been successfully loaded.
The XGBoost_Classifier model has been successfully loaded.
Single Models load ok!
INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
Number of GPUs: 1
HybridModel load ok!
Scaler load ok!
Logistic_Regression           ===> [0.39534222709231687]
Decision_Trees_Classifier     ===> [1.0]
Random_Forest_Classifier      ===> [0.6]
XGBoost_Classifier            ===> [0.76530826]
WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f9ff04bff60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step
meta_model  ===> [0.1]
Processed address: 0x7b83c834317bb1851506aa74c46b252584805b1c, Result: [0.1]
Processed address: 0x7b83c834317bb1851506aa74c46b252584805b1c
Processing address: 0x000000000057a6ded7c7f9260355ef32e2b997c0
getTxHashInfo done! Execution time: 0.6765613555908203 s
getVerifyTagInfo done! Execution time: 0.33736157417297363 s
https://eth-mainnet.g.alchemy.com/v2/6t0LpEw9cr0OlGIVTFqs92aOIkfhktMk
getTxInfo done! Execution time: 0.33565759658813477 s
https://eth-mainnet.g.alchemy.com/v2/6t0LpEw9cr0OlGIVTFqs92aOIkfhktMk
getCode response: {"jsonrpc":"2.0","id":1,"result":"..."}
getBytecodeInfo done! Execution time: 0.5364375114440918 s
getGasUsedInfo done! Execution time: 0.16739130020141602 s
Error querying address 0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x4ce3687fed17e19324f23e305593ab13bbd55c4d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x7a250d5630b4cf539739df2c5dacb4c659f2488d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x4ce3687fed17e19324f23e305593ab13bbd55c4d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x970b9bb2c0444f5e81e9d0efb84c8ccdcdcaf84d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x970b9bb2c0444f5e81e9d0efb84c8ccdcdcaf84d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xbbce03b2e7f53cadca93251ca4c928af01db6404: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xbbce03b2e7f53cadca93251ca4c928af01db6404: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xbbce03b2e7f53cadca93251ca4c928af01db6404: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xbbce03b2e7f53cadca93251ca4c928af01db6404: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x970b9bb2c0444f5e81e9d0efb84c8ccdcdcaf84d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x4ce3687fed17e19324f23e305593ab13bbd55c4d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x7a250d5630b4cf539739df2c5dacb4c659f2488d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x4ce3687fed17e19324f23e305593ab13bbd55c4d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x4ce3687fed17e19324f23e305593ab13bbd55c4d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
getGigahorseInfo done! Execution time: 18.581292867660522 s
Total execution time: 20.63470220565796 s
Gigahorse status: OK
The Logistic_Regression model has been successfully loaded.
The Decision_Trees_Classifier model has been successfully loaded.
The Random_Forest_Classifier model has been successfully loaded.
The XGBoost_Classifier model has been successfully loaded.
Single Models load ok!
INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
Number of GPUs: 1
HybridModel load ok!
Scaler load ok!
Logistic_Regression           ===> [0.9837386464556149]
Decision_Trees_Classifier     ===> [1.0]
Random_Forest_Classifier      ===> [1.0]
XGBoost_Classifier            ===> [0.99854493]
1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step
meta_model  ===> [1.0]
Processed address: 0x000000000057a6ded7c7f9260355ef32e2b997c0, Result: [1.0]
Processed address: 0x000000000057a6ded7c7f9260355ef32e2b997c0
Processing address: 0x024e646d0342c61aebfcc6948d3667ae5aea638e
getTxHashInfo done! Execution time: 0.661348819732666 s
getVerifyTagInfo done! Execution time: 0.33725595474243164 s
https://eth-mainnet.g.alchemy.com/v2/6t0LpEw9cr0OlGIVTFqs92aOIkfhktMk
getTxInfo done! Execution time: 0.32842588424682617 s
https://eth-mainnet.g.alchemy.com/v2/6t0LpEw9cr0OlGIVTFqs92aOIkfhktMk
getCode response: {"jsonrpc":"2.0","id":1,"result":"..."}
getBytecodeInfo done! Execution time: 0.5221800804138184 s
getGasUsedInfo done! Execution time: 0.1593794822692871 s
getGigahorseInfo done! Execution time: 18.06729245185852 s
Total execution time: 20.07588267326355 s
Gigahorse status: OK
The Logistic_Regression model has been successfully loaded.
The Decision_Trees_Classifier model has been successfully loaded.
The Random_Forest_Classifier model has been successfully loaded.
The XGBoost_Classifier model has been successfully loaded.
Single Models load ok!
INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
Number of GPUs: 1
HybridModel load ok!
Scaler load ok!
Logistic_Regression           ===> [0.536276523046765]
Decision_Trees_Classifier     ===> [0.0]
Random_Forest_Classifier      ===> [0.4]
XGBoost_Classifier            ===> [0.9942953]
1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step
meta_model  ===> [1.0]
Processed address: 0x024e646d0342c61aebfcc6948d3667ae5aea638e, Result: [1.0]
Processed address: 0x024e646d0342c61aebfcc6948d3667ae5aea638e
Processing address: 0x0000000000c4faebd587ca26cd5b93867b8625f1
getTxHashInfo done! Execution time: 0.6697845458984375 s
getVerifyTagInfo done! Execution time: 0.3358340263366699 s
https://eth-mainnet.g.alchemy.com/v2/6t0LpEw9cr0OlGIVTFqs92aOIkfhktMk
getTxInfo done! Execution time: 0.3144252300262451 s
https://eth-mainnet.g.alchemy.com/v2/6t0LpEw9cr0OlGIVTFqs92aOIkfhktMk
getCode response: {"jsonrpc":"2.0","id":1,"result":"..."}
getBytecodeInfo done! Execution time: 0.49805140495300293 s
getGasUsedInfo done! Execution time: 0.14881467819213867 s
Error querying address 0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x4ce3687fed17e19324f23e305593ab13bbd55c4d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x7a250d5630b4cf539739df2c5dacb4c659f2488d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x4ce3687fed17e19324f23e305593ab13bbd55c4d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x970b9bb2c0444f5e81e9d0efb84c8ccdcdcaf84d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x970b9bb2c0444f5e81e9d0efb84c8ccdcdcaf84d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xbbce03b2e7f53cadca93251ca4c928af01db6404: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xbbce03b2e7f53cadca93251ca4c928af01db6404: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xbbce03b2e7f53cadca93251ca4c928af01db6404: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xbbce03b2e7f53cadca93251ca4c928af01db6404: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x970b9bb2c0444f5e81e9d0efb84c8ccdcdcaf84d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x4ce3687fed17e19324f23e305593ab13bbd55c4d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x7a250d5630b4cf539739df2c5dacb4c659f2488d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x4ce3687fed17e19324f23e305593ab13bbd55c4d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x4ce3687fed17e19324f23e305593ab13bbd55c4d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
getGigahorseInfo done! Execution time: 17.94652509689331 s
Total execution time: 19.913434982299805 s
Gigahorse status: OK
The Logistic_Regression model has been successfully loaded.
The Decision_Trees_Classifier model has been successfully loaded.
The Random_Forest_Classifier model has been successfully loaded.
The XGBoost_Classifier model has been successfully loaded.
Single Models load ok!
INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
Number of GPUs: 1
HybridModel load ok!
Scaler load ok!
Logistic_Regression           ===> [0.9807918659867604]
Decision_Trees_Classifier     ===> [1.0]
Random_Forest_Classifier      ===> [1.0]
XGBoost_Classifier            ===> [0.9982009]
1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step
meta_model  ===> [0.9]
Processed address: 0x0000000000c4faebd587ca26cd5b93867b8625f1, Result: [0.9]
Processed address: 0x0000000000c4faebd587ca26cd5b93867b8625f1
Processing address: 0x528a1b858223f7c6031db235a2210e1a15bf4e5f
getTxHashInfo done! Execution time: 2.2891297340393066 s
getVerifyTagInfo done! Execution time: 0.32616233825683594 s
https://eth-mainnet.g.alchemy.com/v2/6t0LpEw9cr0OlGIVTFqs92aOIkfhktMk
getTxInfo done! Execution time: 0.3093864917755127 s
https://eth-mainnet.g.alchemy.com/v2/6t0LpEw9cr0OlGIVTFqs92aOIkfhktMk
getCode response: {"jsonrpc":"2.0","id":1,"result":"..."}
getBytecodeInfo done! Execution time: 0.5172021389007568 s
getGasUsedInfo done! Execution time: 0.1435854434967041 s
getGigahorseInfo done! Execution time: 15.11571192741394 s
Total execution time: 18.701178073883057 s
Gigahorse status: OK
The Logistic_Regression model has been successfully loaded.
The Decision_Trees_Classifier model has been successfully loaded.
The Random_Forest_Classifier model has been successfully loaded.
The XGBoost_Classifier model has been successfully loaded.
Single Models load ok!
INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
Number of GPUs: 1
HybridModel load ok!
Scaler load ok!
Logistic_Regression           ===> [0.13457079409033962]
Decision_Trees_Classifier     ===> [0.0]
Random_Forest_Classifier      ===> [0.6]
XGBoost_Classifier            ===> [0.20457497]
1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step
meta_model  ===> [0.3]
Processed address: 0x528a1b858223f7c6031db235a2210e1a15bf4e5f, Result: [0.3]
Processed address: 0x528a1b858223f7c6031db235a2210e1a15bf4e5f
Processing address: 0x60dca8e36b27ac74fc2daff71ba8954d63ec0ec6
getTxHashInfo done! Execution time: 1.7104864120483398 s
getVerifyTagInfo done! Execution time: 0.35318732261657715 s
https://eth-mainnet.g.alchemy.com/v2/6t0LpEw9cr0OlGIVTFqs92aOIkfhktMk
getTxInfo done! Execution time: 0.6540946960449219 s
https://eth-mainnet.g.alchemy.com/v2/6t0LpEw9cr0OlGIVTFqs92aOIkfhktMk
getCode response: {"jsonrpc":"2.0","id":1,"result":"..."}
getBytecodeInfo done! Execution time: 0.7823953628540039 s
getGasUsedInfo done! Execution time: 0.14776372909545898 s
Error querying address 0x4ce3687fed17e19324f23e305593ab13bbd55c4d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x4ce3687fed17e19324f23e305593ab13bbd55c4d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x970b9bb2c0444f5e81e9d0efb84c8ccdcdcaf84d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x970b9bb2c0444f5e81e9d0efb84c8ccdcdcaf84d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xbbce03b2e7f53cadca93251ca4c928af01db6404: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xbbce03b2e7f53cadca93251ca4c928af01db6404: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xbbce03b2e7f53cadca93251ca4c928af01db6404: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xbbce03b2e7f53cadca93251ca4c928af01db6404: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xbbce03b2e7f53cadca93251ca4c928af01db6404: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x970b9bb2c0444f5e81e9d0efb84c8ccdcdcaf84d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x4ce3687fed17e19324f23e305593ab13bbd55c4d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x4ce3687fed17e19324f23e305593ab13bbd55c4d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x4ce3687fed17e19324f23e305593ab13bbd55c4d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
getGigahorseInfo done! Execution time: 18.767314672470093 s
Total execution time: 22.415242195129395 s
Gigahorse status: OK
The Logistic_Regression model has been successfully loaded.
The Decision_Trees_Classifier model has been successfully loaded.
The Random_Forest_Classifier model has been successfully loaded.
The XGBoost_Classifier model has been successfully loaded.
Single Models load ok!
INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
Number of GPUs: 1
HybridModel load ok!
Scaler load ok!
Logistic_Regression           ===> [0.9834735827182916]
Decision_Trees_Classifier     ===> [1.0]
Random_Forest_Classifier      ===> [1.0]
XGBoost_Classifier            ===> [0.9994555]
1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step
meta_model  ===> [1.0]
Processed address: 0x60dca8e36b27ac74fc2daff71ba8954d63ec0ec6, Result: [1.0]
Processed address: 0x60dca8e36b27ac74fc2daff71ba8954d63ec0ec6
Processing address: 0x49de0cfc7a9563107d9cecd25c3939b16b84743b
getTxHashInfo done! Execution time: 0.6514761447906494 s
getVerifyTagInfo done! Execution time: 0.32892918586730957 s
https://eth-mainnet.g.alchemy.com/v2/6t0LpEw9cr0OlGIVTFqs92aOIkfhktMk
getTxInfo done! Execution time: 0.30483078956604004 s
https://eth-mainnet.g.alchemy.com/v2/6t0LpEw9cr0OlGIVTFqs92aOIkfhktMk
getCode response: {"jsonrpc":"2.0","id":1,"result":"..."}
getBytecodeInfo done! Execution time: 0.48532557487487793 s
getGasUsedInfo done! Execution time: 0.15285372734069824 s
getGigahorseInfo done! Execution time: 8.799899339675903 s
Total execution time: 10.723314762115479 s
Gigahorse status: OK
The Logistic_Regression model has been successfully loaded.
The Decision_Trees_Classifier model has been successfully loaded.
The Random_Forest_Classifier model has been successfully loaded.
The XGBoost_Classifier model has been successfully loaded.
Single Models load ok!
INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
Number of GPUs: 1
HybridModel load ok!
Scaler load ok!
Logistic_Regression           ===> [0.575029415073893]
Decision_Trees_Classifier     ===> [1.0]
Random_Forest_Classifier      ===> [0.8]
XGBoost_Classifier            ===> [0.9986016]
1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step
meta_model  ===> [1.0]
Processed address: 0x49de0cfc7a9563107d9cecd25c3939b16b84743b, Result: [1.0]
Processed address: 0x49de0cfc7a9563107d9cecd25c3939b16b84743b
Processing address: 0xd22cb69efe88a73c96d2e2eca224251e565976a6
getTxHashInfo done! Execution time: 0.6058831214904785 s
getVerifyTagInfo done! Execution time: 0.3284573554992676 s
https://eth-mainnet.g.alchemy.com/v2/6t0LpEw9cr0OlGIVTFqs92aOIkfhktMk
getTxInfo done! Execution time: 0.3443734645843506 s
https://eth-mainnet.g.alchemy.com/v2/6t0LpEw9cr0OlGIVTFqs92aOIkfhktMk
getCode response: {"jsonrpc":"2.0","id":1,"result":"..."}
getBytecodeInfo done! Execution time: 0.5195558071136475 s
getGasUsedInfo done! Execution time: 0.14209580421447754 s
Error querying address 0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x7a250d5630b4cf539739df2c5dacb4c659f2488d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x3fa1216ca613497d038ef0ef680b4a6b3f7b5f7d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x3fa1216ca613497d038ef0ef680b4a6b3f7b5f7d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xfbbb2f9560b3d1269cc92c0aaaff109f46e57b78: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x3fa1216ca613497d038ef0ef680b4a6b3f7b5f7d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x3fa1216ca613497d038ef0ef680b4a6b3f7b5f7d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xfbbb2f9560b3d1269cc92c0aaaff109f46e57b78: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xba12222222228d8ba445958a75a0704d566bf2c8: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
getGigahorseInfo done! Execution time: 8.085156679153442 s
Total execution time: 10.025522232055664 s
Gigahorse status: OK
The Logistic_Regression model has been successfully loaded.
The Decision_Trees_Classifier model has been successfully loaded.
The Random_Forest_Classifier model has been successfully loaded.
The XGBoost_Classifier model has been successfully loaded.
Single Models load ok!
INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
Number of GPUs: 1
HybridModel load ok!
Scaler load ok!
Logistic_Regression           ===> [0.7748152787939222]
Decision_Trees_Classifier     ===> [1.0]
Random_Forest_Classifier      ===> [1.0]
XGBoost_Classifier            ===> [0.9983388]
1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step
meta_model  ===> [1.0]
Processed address: 0xd22cb69efe88a73c96d2e2eca224251e565976a6, Result: [1.0]
Processed address: 0xd22cb69efe88a73c96d2e2eca224251e565976a6
Processing address: 0xe3b9bd5145286725653bfdcf3bfafecda2f69a90
getTxHashInfo done! Execution time: 0.5510978698730469 s
getVerifyTagInfo done! Execution time: 0.26957178115844727 s
https://eth-mainnet.g.alchemy.com/v2/6t0LpEw9cr0OlGIVTFqs92aOIkfhktMk
getTxInfo done! Execution time: 0.31157422065734863 s
https://eth-mainnet.g.alchemy.com/v2/6t0LpEw9cr0OlGIVTFqs92aOIkfhktMk
getCode response: {"jsonrpc":"2.0","id":1,"result":"..."}
getBytecodeInfo done! Execution time: 0.5264618396759033 s
getGasUsedInfo done! Execution time: 0.1325240135192871 s
getGigahorseInfo done! Execution time: 7.362904071807861 s
Total execution time: 9.154133796691895 s
Gigahorse status: OK
The Logistic_Regression model has been successfully loaded.
The Decision_Trees_Classifier model has been successfully loaded.
The Random_Forest_Classifier model has been successfully loaded.
The XGBoost_Classifier model has been successfully loaded.
Single Models load ok!
INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
Number of GPUs: 1
HybridModel load ok!
Scaler load ok!
Logistic_Regression           ===> [0.9398479631768049]
Decision_Trees_Classifier     ===> [1.0]
Random_Forest_Classifier      ===> [0.8]
XGBoost_Classifier            ===> [0.98571175]
1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step
meta_model  ===> [1.0]
Processed address: 0xe3b9bd5145286725653bfdcf3bfafecda2f69a90, Result: [1.0]
Processed address: 0xe3b9bd5145286725653bfdcf3bfafecda2f69a90
Processing address: 0x00000000008691a9b04d28fb59e8b6526fc341a6
getTxHashInfo done! Execution time: 0.6485652923583984 s
getVerifyTagInfo done! Execution time: 0.34351658821105957 s
https://eth-mainnet.g.alchemy.com/v2/6t0LpEw9cr0OlGIVTFqs92aOIkfhktMk
getTxInfo done! Execution time: 0.315035343170166 s
https://eth-mainnet.g.alchemy.com/v2/6t0LpEw9cr0OlGIVTFqs92aOIkfhktMk
getCode response: {"jsonrpc":"2.0","id":1,"result":"..."}
getBytecodeInfo done! Execution time: 0.5010159015655518 s
getGasUsedInfo done! Execution time: 0.13784480094909668 s
Error querying address 0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x4ce3687fed17e19324f23e305593ab13bbd55c4d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x7a250d5630b4cf539739df2c5dacb4c659f2488d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x4ce3687fed17e19324f23e305593ab13bbd55c4d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x970b9bb2c0444f5e81e9d0efb84c8ccdcdcaf84d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x970b9bb2c0444f5e81e9d0efb84c8ccdcdcaf84d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xbbce03b2e7f53cadca93251ca4c928af01db6404: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xbbce03b2e7f53cadca93251ca4c928af01db6404: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xbbce03b2e7f53cadca93251ca4c928af01db6404: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x970b9bb2c0444f5e81e9d0efb84c8ccdcdcaf84d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x4ce3687fed17e19324f23e305593ab13bbd55c4d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x7a250d5630b4cf539739df2c5dacb4c659f2488d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x4ce3687fed17e19324f23e305593ab13bbd55c4d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x4ce3687fed17e19324f23e305593ab13bbd55c4d: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
Error querying address 0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
getGigahorseInfo done! Execution time: 14.995979309082031 s
Total execution time: 16.941957235336304 s
Gigahorse status: OK
The Logistic_Regression model has been successfully loaded.
The Decision_Trees_Classifier model has been successfully loaded.
The Random_Forest_Classifier model has been successfully loaded.
The XGBoost_Classifier model has been successfully loaded.
Single Models load ok!
INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
Number of GPUs: 1
HybridModel load ok!
Scaler load ok!
Logistic_Regression           ===> [0.9732212639701915]
Decision_Trees_Classifier     ===> [1.0]
Random_Forest_Classifier      ===> [1.0]
XGBoost_Classifier            ===> [0.997769]
1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step
meta_model  ===> [0.9]
Processed address: 0x00000000008691a9b04d28fb59e8b6526fc341a6, Result: [0.9]
Processed address: 0x00000000008691a9b04d28fb59e8b6526fc341a6
Processing address: 0x2d89fb83c66b6c7c35818382517959e33a655b13
getTxHashInfo done! Execution time: 0.6679177284240723 s
getVerifyTagInfo done! Execution time: 0.3405938148498535 s
https://eth-mainnet.g.alchemy.com/v2/6t0LpEw9cr0OlGIVTFqs92aOIkfhktMk
getTxInfo done! Execution time: 0.3151257038116455 s
https://eth-mainnet.g.alchemy.com/v2/6t0LpEw9cr0OlGIVTFqs92aOIkfhktMk
getCode response: {"jsonrpc":"2.0","id":1,"result":"..."}
getBytecodeInfo done! Execution time: 0.5103626251220703 s
getGasUsedInfo done! Execution time: 0.14367008209228516 s
getGigahorseInfo done! Execution time: 15.322367668151855 s
Total execution time: 17.300037622451782 s
Gigahorse status: OK
The Logistic_Regression model has been successfully loaded.
The Decision_Trees_Classifier model has been successfully loaded.
The Random_Forest_Classifier model has been successfully loaded.
The XGBoost_Classifier model has been successfully loaded.
Single Models load ok!
INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
Number of GPUs: 1
HybridModel load ok!
Scaler load ok!
Logistic_Regression           ===> [0.7090312204184069]
Decision_Trees_Classifier     ===> [1.0]
Random_Forest_Classifier      ===> [1.0]
XGBoost_Classifier            ===> [0.9956416]
1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step
meta_model  ===> [1.0]
Processed address: 0x2d89fb83c66b6c7c35818382517959e33a655b13, Result: [1.0]
Processed address: 0x2d89fb83c66b6c7c35818382517959e33a655b13
Processing address: 0xd71875b54a0c8c0061ad0898a554849b3640d3e2
getTxHashInfo done! Execution time: 0.6585378646850586 s
getVerifyTagInfo done! Execution time: 0.33846473693847656 s
https://eth-mainnet.g.alchemy.com/v2/6t0LpEw9cr0OlGIVTFqs92aOIkfhktMk
getTxInfo done! Execution time: 0.3142588138580322 s
https://eth-mainnet.g.alchemy.com/v2/6t0LpEw9cr0OlGIVTFqs92aOIkfhktMk
getCode response: {"jsonrpc":"2.0","id":1,"result":"..."}
getBytecodeInfo done! Execution time: 0.5785608291625977 s
getGasUsedInfo done! Execution time: 0.13553953170776367 s
getGigahorseInfo done! Execution time: 12.351805686950684 s
Total execution time: 14.377167463302612 s
Gigahorse status: OK
The Logistic_Regression model has been successfully loaded.
The Decision_Trees_Classifier model has been successfully loaded.
The Random_Forest_Classifier model has been successfully loaded.
The XGBoost_Classifier model has been successfully loaded.
Single Models load ok!
INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
Number of GPUs: 1
HybridModel load ok!
Scaler load ok!
Logistic_Regression           ===> [0.9808646711669737]
Decision_Trees_Classifier     ===> [1.0]
Random_Forest_Classifier      ===> [0.8]
XGBoost_Classifier            ===> [0.9998541]
1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
meta_model  ===> [0.9]
Processed address: 0xd71875b54a0c8c0061ad0898a554849b3640d3e2, Result: [0.9]
Processed address: 0xd71875b54a0c8c0061ad0898a554849b3640d3e2
Processing address: 0xc1e91f02909e781a84390536ae100018676f40b8
getTxHashInfo done! Execution time: 0.5561542510986328 s
getVerifyTagInfo done! Execution time: 0.32901501655578613 s
https://eth-mainnet.g.alchemy.com/v2/6t0LpEw9cr0OlGIVTFqs92aOIkfhktMk
getTxInfo done! Execution time: 0.32941603660583496 s
https://eth-mainnet.g.alchemy.com/v2/6t0LpEw9cr0OlGIVTFqs92aOIkfhktMk
getCode response: {"jsonrpc":"2.0","id":1,"result":"..."}
getBytecodeInfo done! Execution time: 0.5418062210083008 s
getGasUsedInfo done! Execution time: 0.15458917617797852 s
getGigahorseInfo done! Execution time: 19.179442167282104 s
Total execution time: 21.090422868728638 s
Gigahorse status: OK
The Logistic_Regression model has been successfully loaded.
The Decision_Trees_Classifier model has been successfully loaded.
The Random_Forest_Classifier model has been successfully loaded.
The XGBoost_Classifier model has been successfully loaded.
Single Models load ok!
INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
Number of GPUs: 1
HybridModel load ok!
Scaler load ok!
Logistic_Regression           ===> [0.5043824888967915]
Decision_Trees_Classifier     ===> [0.0]
Random_Forest_Classifier      ===> [0.4]
XGBoost_Classifier            ===> [0.74985105]
1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
meta_model  ===> [1.0]
Processed address: 0xc1e91f02909e781a84390536ae100018676f40b8, Result: [1.0]
Processed address: 0xc1e91f02909e781a84390536ae100018676f40b8
Processing address: 0x004e4ceb12096d9ccd03efd342b8c2a794293032
"""

# 使用正则表达式提取地址和结果
pattern = r"Processed address: (\w+), Result: \[(\d+\.\d+)\]"
matches = re.findall(pattern, log_content)

# 将结果存储到字典中
results = {address: [float(result)] for address, result in matches}

print(results)
# Out:
# {'0x6dab590b90e6ab94d6031fb39dd21b4776ee4684': [0.3], '0x2a6aa49b9138b66ba2b81c33435d01c84848afbc': [0.1], '0x193E045BeE45C7573Ff89b12601C745AF739CE67': [0.6], '0x21a624e893e43d2d36b178fd258ec465aba0ed55': [0.3], '0xb65c2ba401d5fcb60dfa748fe80b69525c47fd5e': [0.9], '0x7b83c834317bb1851506aa74c46b252584805b1c': [0.1], '0x000000000057a6ded7c7f9260355ef32e2b997c0': [1.0], '0x024e646d0342c61aebfcc6948d3667ae5aea638e': [1.0], '0x0000000000c4faebd587ca26cd5b93867b8625f1': [0.9], '0x528a1b858223f7c6031db235a2210e1a15bf4e5f': [0.3], '0x60dca8e36b27ac74fc2daff71ba8954d63ec0ec6': [1.0], '0x49de0cfc7a9563107d9cecd25c3939b16b84743b': [1.0], '0xd22cb69efe88a73c96d2e2eca224251e565976a6': [1.0], '0xe3b9bd5145286725653bfdcf3bfafecda2f69a90': [1.0], '0x00000000008691a9b04d28fb59e8b6526fc341a6': [0.9], '0x2d89fb83c66b6c7c35818382517959e33a655b13': [1.0], '0xd71875b54a0c8c0061ad0898a554849b3640d3e2': [0.9], '0xc1e91f02909e781a84390536ae100018676f40b8': [1.0]}
